# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score

# %%
matches = pd.read_csv("matches.csv", index_col = 0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result  gf  ga  \
# 1  2023-08-11  20:00  Premier League  Matchweek 1  Fri  Away      W   3   0
# 3  2023-08-19  20:00  Premier League  Matchweek 2  Sat  Home      W   1   0
# 4  2023-08-27  14:00  Premier League  Matchweek 3  Sun  Away      W   2   1
# 5  2023-09-02  15:00  Premier League  Matchweek 4  Sat  Home      W   5   1
# 6  2023-09-16  15:00  Premier League  Matchweek 5  Sat  Away      W   3   1
#
#         opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 1        Burnley  ...  Match Report    NaN  17.0   8.0  13.9  0.0  0     0
# 3  Newcastle Utd  ...  Match Report    NaN  14.0   4.0  17.9  0.0  0     0
# 4  Sheffield Utd  ...  Match Report    NaN  29.0   9.0  17.3  2.0  0     1
# 5         Fulham  ...  Match Report    NaN   6.0   4.0  14.8  0.0  1     1
# 6       West Ham  ...  Match Report    NaN  29.0  13.0  16.4  1.0  0     0
#
#    season             team
# 1    2024  Manchester City
# 3    2024  Manchester City
# 4    2024  Manchester City
# 5    2024  Manchester City
# 6    2024  Manchester City
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (3040, 27)

# %%
matches[matches['team'] == "Liverpool"]
# Out:
#           date   time            comp         round  day venue result  gf  ga  \
# 0   2023-08-13  16:30  Premier League   Matchweek 1  Sun  Away      D   1   1
# 1   2023-08-19  15:00  Premier League   Matchweek 2  Sat  Home      W   3   1
# 2   2023-08-27  16:30  Premier League   Matchweek 3  Sun  Away      W   2   1
# 3   2023-09-03  14:00  Premier League   Matchweek 4  Sun  Home      W   3   0
# 4   2023-09-16  12:30  Premier League   Matchweek 5  Sat  Away      W   3   1
# ..         ...    ...             ...           ...  ...   ...    ...  ..  ..
# 48  2021-05-08  20:15  Premier League  Matchweek 35  Sat  Home      W   2   0
# 49  2021-05-13  20:15  Premier League  Matchweek 34  Thu  Away      W   4   2
# 50  2021-05-16  16:30  Premier League  Matchweek 36  Sun  Away      W   2   1
# 51  2021-05-19  20:15  Premier League  Matchweek 37  Wed  Away      W   3   0
# 52  2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W   2   0
#
#           opponent  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# 0          Chelsea  ...  Match Report    NaN  13.0  1.0  17.8  0.0  0     0
# 1      Bournemouth  ...  Match Report    NaN  25.0  9.0  16.8  1.0  0     1
# 2    Newcastle Utd  ...  Match Report    NaN   9.0  4.0  17.2  1.0  0     0
# 3      Aston Villa  ...  Match Report    NaN  17.0  4.0  14.7  0.0  0     0
# 4           Wolves  ...  Match Report    NaN  16.0  5.0  15.8  0.0  0     0
# ..             ...  ...           ...    ...   ...  ...   ...  ... ..   ...
# 48     Southampton  ...  Match Report    NaN  14.0  6.0  13.6  0.0  0     0
# 49  Manchester Utd  ...  Match Report    NaN  17.0  8.0  14.9  0.0  0     0
# 50       West Brom  ...  Match Report    NaN  26.0  6.0  18.3  1.0  0     0
# 51         Burnley  ...  Match Report    NaN  20.0  3.0  16.2  1.0  0     0
# 52  Crystal Palace  ...  Match Report    NaN  19.0  5.0  14.7  1.0  0     0
#
#     season       team
# 0     2024  Liverpool
# 1     2024  Liverpool
# 2     2024  Liverpool
# 3     2024  Liverpool
# 4     2024  Liverpool
# ..     ...        ...
# 48    2021  Liverpool
# 49    2021  Liverpool
# 50    2021  Liverpool
# 51    2021  Liverpool
# 52    2021  Liverpool
#
# [152 rows x 27 columns]

# %%
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                       int64
# ga                       int64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                       int64
# pkatt                    int64
# season                   int64
# team                    object
# venue_code                int8
# opp_code                  int8
# hour                     int64
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches['date'])
matches["venue_code"] = matches["venue"].astype("category").cat.codes
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")
matches["day_code"] = matches["date"].dt.dayofweek
matches["target"] = (matches["result"] == "W").astype("int")

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2023-01-01']
test = matches[matches["date"] > '2023-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.6153198653198653

# %%
combined = pd.DataFrame(dict(actual = test["target"], prediction = preds))

# %%
pd.crosstab(index = combined["actual"], columns = combined["prediction"])
# Out:
# prediction    0    1
# actual
# 0           578  147
# 1           310  153

# %%
precision_score(test["target"], preds)
# Out:
# 0.51

# %%
grouped_matches = matches.groupby("team")
group = grouped_matches.get_group("Liverpool")

# %%
group
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 0  2023-08-13  16:30  Premier League   Matchweek 1  Sun  Away      D   1   1
# 1  2023-08-19  15:00  Premier League   Matchweek 2  Sat  Home      W   3   1
# 2  2023-08-27  16:30  Premier League   Matchweek 3  Sun  Away      W   2   1
# 3  2023-09-03  14:00  Premier League   Matchweek 4  Sun  Home      W   3   0
# 4  2023-09-16  12:30  Premier League   Matchweek 5  Sat  Away      W   3   1
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 48 2021-05-08  20:15  Premier League  Matchweek 35  Sat  Home      W   2   0
# 49 2021-05-13  20:15  Premier League  Matchweek 34  Thu  Away      W   4   2
# 50 2021-05-16  16:30  Premier League  Matchweek 36  Sun  Away      W   2   1
# 51 2021-05-19  20:15  Premier League  Matchweek 37  Wed  Away      W   3   0
# 52 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W   2   0
#
#           opponent  ...   fk  pk  pkatt  season       team venue_code  \
# 0          Chelsea  ...  0.0   0      0    2024  Liverpool          0
# 1      Bournemouth  ...  1.0   0      1    2024  Liverpool          1
# 2    Newcastle Utd  ...  1.0   0      0    2024  Liverpool          0
# 3      Aston Villa  ...  0.0   0      0    2024  Liverpool          1
# 4           Wolves  ...  0.0   0      0    2024  Liverpool          0
# ..             ...  ...  ...  ..    ...     ...        ...        ...
# 48     Southampton  ...  0.0   0      0    2021  Liverpool          1
# 49  Manchester Utd  ...  0.0   0      0    2021  Liverpool          0
# 50       West Brom  ...  1.0   0      0    2021  Liverpool          0
# 51         Burnley  ...  1.0   0      0    2021  Liverpool          0
# 52  Crystal Palace  ...  1.0   0      0    2021  Liverpool          1
#
#    opp_code hour  day_code  target
# 0         6   16         6       0
# 1         2   15         5       1
# 2        16   16         6       1
# 3         1   14         6       1
# 4        25   12         5       1
# ..      ...  ...       ...     ...
# 48       20   20         5       1
# 49       15   20         3       1
# 50       23   16         6       1
# 51        5   20         2       1
# 52        7   16         6       1
#
# [152 rows x 32 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed = 'left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 6  2020-10-04  19:15  Premier League   Matchweek 4  Sun  Away      L   2   7
# 7  2020-10-17  12:30  Premier League   Matchweek 5  Sat  Away      D   2   2
# 9  2020-10-24  20:00  Premier League   Matchweek 6  Sat  Home      W   2   1
# 11 2020-10-31  17:30  Premier League   Matchweek 7  Sat  Home      W   2   1
# 13 2020-11-08  16:30  Premier League   Matchweek 8  Sun  Away      D   1   1
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 53 2024-04-24  20:00  Premier League  Matchweek 29  Wed  Away      L   0   2
# 54 2024-04-27  12:30  Premier League  Matchweek 35  Sat  Away      D   2   2
# 55 2024-05-05  16:30  Premier League  Matchweek 36  Sun  Home      W   4   2
# 56 2024-05-13  20:00  Premier League  Matchweek 37  Mon  Away      D   3   3
# 57 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Home      W   2   0
#
#            opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 6       Aston Villa  ...         6       0    3.000000    1.333333  19.666667
# 7           Everton  ...         5       0    2.333333    2.666667  17.666667
# 9     Sheffield Utd  ...         5       1    2.333333    3.333333  19.000000
# 11         West Ham  ...         5       1    2.000000    3.333333  17.666667
# 13  Manchester City  ...         6       0    2.000000    1.333333  15.666667
# ..              ...  ...       ...     ...         ...         ...        ...
# 53          Everton  ...         2       0    1.666667    1.333333  20.666667
# 54         West Ham  ...         5       0    1.000000    1.333333  19.333333
# 55        Tottenham  ...         6       1    1.666667    1.666667  21.666667
# 56      Aston Villa  ...         0       0    2.000000    2.000000  25.333333
# 57           Wolves  ...         6       1    3.000000    2.333333  22.333333
#
#    sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 6     5.666667    18.166667   0.333333    0.666667       0.666667
# 7     7.000000    17.466667   0.666667    0.000000       0.000000
# 9     8.000000    16.733333   1.000000    0.000000       0.000000
# 11    7.000000    17.033333   1.333333    0.000000       0.000000
# 13    5.666667    18.266667   1.333333    0.333333       0.333333
# ..         ...          ...        ...         ...            ...
# 53    6.000000    16.266667   1.000000    0.333333       0.333333
# 54    6.333333    16.033333   1.000000    0.000000       0.000000
# 55    7.333333    17.400000   1.000000    0.000000       0.000000
# 56    9.000000    16.233333   0.333333    0.000000       0.000000
# 57    9.000000    16.333333   0.333333    0.000000       0.000000
#
# [149 rows x 40 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 6  2020-10-04  14:00  Premier League   Matchweek 4
#                         7  2020-10-17  17:30  Premier League   Matchweek 5
#                         9  2020-10-25  19:15  Premier League   Matchweek 6
#                         11 2020-11-01  16:30  Premier League   Matchweek 7
#                         13 2020-11-08  19:15  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 40 2024-04-24  19:45  Premier League  Matchweek 29
#                         41 2024-04-27  15:00  Premier League  Matchweek 35
#                         42 2024-05-04  17:30  Premier League  Matchweek 36
#                         43 2024-05-11  15:00  Premier League  Matchweek 37
#                         44 2024-05-19  16:00  Premier League  Matchweek 38
#
#                             day venue result  gf  ga         opponent  ...  \
# team                                                                   ...
# Arsenal                 6   Sun  Home      W   2   1    Sheffield Utd  ...
#                         7   Sat  Away      L   0   1  Manchester City  ...
#                         9   Sun  Home      L   0   1   Leicester City  ...
#                         11  Sun  Away      W   1   0   Manchester Utd  ...
#                         13  Sun  Home      L   0   3      Aston Villa  ...
# ...                         ...   ...    ...  ..  ..              ...  ...
# Wolverhampton Wanderers 40  Wed  Home      L   0   1      Bournemouth  ...
#                         41  Sat  Home      W   2   1       Luton Town  ...
#                         42  Sat  Away      L   1   5  Manchester City  ...
#                         43  Sat  Home      L   1   3   Crystal Palace  ...
#                         44  Sun  Away      L   0   2        Liverpool  ...
#
#                             day_code  target  gf_rolling  ga_rolling  \
# team
# Arsenal                 6          6       1    2.000000    1.333333
#                         7          5       0    1.666667    1.666667
#                         9          6       0    1.000000    1.666667
#                         11         6       1    0.666667    1.000000
#                         13         6       0    0.333333    0.666667
# ...                              ...     ...         ...         ...
# Wolverhampton Wanderers 40         2       0    1.000000    2.000000
#                         41         5       1    0.666667    1.666667
#                         42         5       0    0.666667    1.333333
#                         43         5       0    1.000000    2.333333
#                         44         6       0    1.333333    3.000000
#
#                            sh_rolling sot_rolling dist_rolling fk_rolling  \
# team
# Arsenal                 6    8.000000    3.666667    14.633333   0.666667
#                         7    5.666667    3.666667    15.366667   0.000000
#                         9    7.000000    3.666667    16.566667   0.666667
#                         11   9.666667    4.000000    16.566667   1.000000
#                         13   9.666667    2.666667    19.333333   1.000000
# ...                               ...         ...          ...        ...
# Wolverhampton Wanderers 40   9.666667    4.000000    20.533333   0.333333
#                         41  10.333333    3.333333    18.766667   0.000000
#                         42  11.000000    4.000000    19.666667   0.000000
#                         43  10.000000    3.333333    15.966667   0.000000
#                         44   9.666667    4.666667    14.133333   0.000000
#
#                             pk_rolling  pkatt_rolling
# team
# Arsenal                 6     0.000000       0.000000
#                         7     0.000000       0.000000
#                         9     0.000000       0.000000
#                         11    0.000000       0.000000
#                         13    0.333333       0.333333
# ...                                ...            ...
# Wolverhampton Wanderers 40    0.333333       0.333333
#                         41    0.000000       0.000000
#                         42    0.000000       0.000000
#                         43    0.000000       0.000000
#                         44    0.000000       0.000000
#
# [2959 rows x 40 columns]

# %%
matches_rolling = matches_rolling.droplevel("team")

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#            date   time            comp         round  day venue result  gf  \
# 0    2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W   2
# 1    2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L   0
# 2    2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L   0
# 3    2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W   1
# 4    2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L   0
# ...         ...    ...             ...           ...  ...   ...    ...  ..
# 2954 2024-04-24  19:45  Premier League  Matchweek 29  Wed  Home      L   0
# 2955 2024-04-27  15:00  Premier League  Matchweek 35  Sat  Home      W   2
# 2956 2024-05-04  17:30  Premier League  Matchweek 36  Sat  Away      L   1
# 2957 2024-05-11  15:00  Premier League  Matchweek 37  Sat  Home      L   1
# 2958 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Away      L   0
#
#       ga         opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 0      1    Sheffield Utd  ...         6       1    2.000000    1.333333
# 1      1  Manchester City  ...         5       0    1.666667    1.666667
# 2      1   Leicester City  ...         6       0    1.000000    1.666667
# 3      0   Manchester Utd  ...         6       1    0.666667    1.000000
# 4      3      Aston Villa  ...         6       0    0.333333    0.666667
# ...   ..              ...  ...       ...     ...         ...         ...
# 2954   1      Bournemouth  ...         2       0    1.000000    2.000000
# 2955   1       Luton Town  ...         5       1    0.666667    1.666667
# 2956   5  Manchester City  ...         5       0    0.666667    1.333333
# 2957   3   Crystal Palace  ...         5       0    1.000000    2.333333
# 2958   2        Liverpool  ...         6       0    1.333333    3.000000
#
#      sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 0      8.000000    3.666667    14.633333   0.666667    0.000000       0.000000
# 1      5.666667    3.666667    15.366667   0.000000    0.000000       0.000000
# 2      7.000000    3.666667    16.566667   0.666667    0.000000       0.000000
# 3      9.666667    4.000000    16.566667   1.000000    0.000000       0.000000
# 4      9.666667    2.666667    19.333333   1.000000    0.333333       0.333333
# ...         ...         ...          ...        ...         ...            ...
# 2954   9.666667    4.000000    20.533333   0.333333    0.333333       0.333333
# 2955  10.333333    3.333333    18.766667   0.000000    0.000000       0.000000
# 2956  11.000000    4.000000    19.666667   0.000000    0.000000       0.000000
# 2957  10.000000    3.333333    15.966667   0.000000    0.000000       0.000000
# 2958   9.666667    4.666667    14.133333   0.000000    0.000000       0.000000
#
# [2959 rows x 40 columns]

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2023-01-01']
    test = data[data["date"] > '2023-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.5738831615120275

# %%
combined
# Out:
#       actual  predicted
# 89         0          1
# 90         1          0
# 91         1          0
# 92         0          1
# 93         0          1
# ...      ...        ...
# 2954       0          0
# 2955       1          0
# 2956       0          0
# 2957       0          0
# 2958       0          0
#
# [1185 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined.head(10)
# Out:
#     actual  predicted       date     team         opponent result
# 89       0          1 2023-01-03  Arsenal    Newcastle Utd      D
# 90       1          0 2023-01-15  Arsenal        Tottenham      W
# 91       1          0 2023-01-22  Arsenal   Manchester Utd      W
# 92       0          1 2023-02-04  Arsenal          Everton      L
# 93       0          1 2023-02-11  Arsenal        Brentford      D
# 94       0          0 2023-02-15  Arsenal  Manchester City      L
# 95       1          1 2023-02-18  Arsenal      Aston Villa      W
# 96       1          0 2023-02-25  Arsenal   Leicester City      W
# 97       1          0 2023-03-01  Arsenal          Everton      W
# 98       1          1 2023-03-04  Arsenal      Bournemouth      W

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {
    "Brighton and Hove Albion": "Brighton", 
    "Manchester United": "Manchester Utd", 
    "Newcastle United": "Newcastle Utd", 
    "Tottenham Hotspur": "Tottenham", 
    "West Ham United": "West Ham", 
    "Wolverhampton Wanderers": "Wolves"
} 
mapping = MissingDict(**map_values)

# %%
mapping["Arsenal"]
# Out:
# 'Arsenal'

# %%
mapping["Tottenham Hotspur"]
# Out:
# 'Tottenham'

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
combined
# Out:
#       actual  predicted       date                     team         opponent  \
# 89         0          1 2023-01-03                  Arsenal    Newcastle Utd
# 90         1          0 2023-01-15                  Arsenal        Tottenham
# 91         1          0 2023-01-22                  Arsenal   Manchester Utd
# 92         0          1 2023-02-04                  Arsenal          Everton
# 93         0          1 2023-02-11                  Arsenal        Brentford
# ...      ...        ...        ...                      ...              ...
# 2954       0          0 2024-04-24  Wolverhampton Wanderers      Bournemouth
# 2955       1          0 2024-04-27  Wolverhampton Wanderers       Luton Town
# 2956       0          0 2024-05-04  Wolverhampton Wanderers  Manchester City
# 2957       0          0 2024-05-11  Wolverhampton Wanderers   Crystal Palace
# 2958       0          0 2024-05-19  Wolverhampton Wanderers        Liverpool
#
#      result new_team
# 89        D  Arsenal
# 90        W  Arsenal
# 91        W  Arsenal
# 92        L  Arsenal
# 93        D  Arsenal
# ...     ...      ...
# 2954      L   Wolves
# 2955      W   Wolves
# 2956      L   Wolves
# 2957      L   Wolves
# 2958      L   Wolves
#
# [1185 rows x 7 columns]

# %%
merged = combined.merge(combined, left_on=['date', 'new_team'], right_on=['date', 'opponent'])

# %%
merged
# Out:
#       actual_x  predicted_x       date                   team_x  \
# 0            0            1 2023-01-03                  Arsenal
# 1            1            0 2023-01-15                  Arsenal
# 2            1            0 2023-01-22                  Arsenal
# 3            0            1 2023-02-04                  Arsenal
# 4            0            1 2023-02-11                  Arsenal
# ...        ...          ...        ...                      ...
# 1080         0            0 2024-04-24  Wolverhampton Wanderers
# 1081         1            0 2024-04-27  Wolverhampton Wanderers
# 1082         0            0 2024-05-04  Wolverhampton Wanderers
# 1083         0            0 2024-05-11  Wolverhampton Wanderers
# 1084         0            0 2024-05-19  Wolverhampton Wanderers
#
#            opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0       Newcastle Utd        D    Arsenal         0            0
# 1           Tottenham        W    Arsenal         0            0
# 2      Manchester Utd        W    Arsenal         0            1
# 3             Everton        L    Arsenal         1            0
# 4           Brentford        D    Arsenal         0            0
# ...               ...      ...        ...       ...          ...
# 1080      Bournemouth        L     Wolves         1            0
# 1081       Luton Town        W     Wolves         0            0
# 1082  Manchester City        L     Wolves         1            1
# 1083   Crystal Palace        L     Wolves         1            0
# 1084        Liverpool        L     Wolves         1            1
#
#                  team_y opponent_y result_y       new_team_y
# 0      Newcastle United    Arsenal        D    Newcastle Utd
# 1     Tottenham Hotspur    Arsenal        L        Tottenham
# 2     Manchester United    Arsenal        L   Manchester Utd
# 3               Everton    Arsenal        W          Everton
# 4             Brentford    Arsenal        D        Brentford
# ...                 ...        ...      ...              ...
# 1080        Bournemouth     Wolves        W      Bournemouth
# 1081         Luton Town     Wolves        L       Luton Town
# 1082    Manchester City     Wolves        W  Manchester City
# 1083     Crystal Palace     Wolves        W   Crystal Palace
# 1084          Liverpool     Wolves        W        Liverpool
#
# [1085 rows x 13 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    154
# 0    102
# Name: count, dtype: int64

# %%
154/256
# Out:
# 0.6015625
